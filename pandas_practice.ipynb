# %%
## PANDAS PRACTICE ######

# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
df = pd.read_csv('pokemon_data.csv')
df.columns
df.index = df['#']
df.drop(['#'],axis=1)
# Out:
#                       Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# #
# 1                Bulbasaur    Grass  Poison  45      49       49       65
# 2                  Ivysaur    Grass  Poison  60      62       63       80
# 3                 Venusaur    Grass  Poison  80      82       83      100
# 3    VenusaurMega Venusaur    Grass  Poison  80     100      123      122
# 4               Charmander     Fire     NaN  39      52       43       60
# ..                     ...      ...     ...  ..     ...      ...      ...
# 719                Diancie     Rock   Fairy  50     100      150      100
# 719    DiancieMega Diancie     Rock   Fairy  50     160      110      160
# 720    HoopaHoopa Confined  Psychic   Ghost  80     110       60      150
# 720     HoopaHoopa Unbound  Psychic    Dark  80     160       60      170
# 721              Volcanion     Fire   Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# #
# ...

# %%
df[['Type 2']].value_counts()
# Out:
# Type 2
# Flying      97
# Ground      35
# Poison      34
# Psychic     33
# Fighting    26
# Grass       25
# Fairy       23
# Steel       22
# Dark        20
# Dragon      18
# Water       14
# Ghost       14
# Ice         14
# Rock        14
# Fire        12
# Electric     6
# Normal       4
# Bug          3
# dtype: int64

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
df= df.rename(columns = {'Type 1':'type1', 'Type 2': 'type2'})

# %%
## check the mean statistics for all types of pokemons
df.groupby(["type1"])[["Speed","Attack","HP","Defense"]].mean()
# Out:
#                Speed      Attack         HP     Defense
# type1
# Bug        61.681159   70.971014  56.884058   70.724638
# Dark       76.161290   88.387097  66.806452   70.225806
# Dragon     83.031250  112.125000  83.312500   86.375000
# Electric   84.500000   69.090909  59.795455   66.295455
# Fairy      48.588235   61.529412  74.117647   65.705882
# Fighting   66.074074   96.777778  69.851852   65.925926
# Fire       74.442308   84.769231  69.903846   67.769231
# Flying    102.500000   78.750000  70.750000   66.250000
# Ghost      64.343750   73.781250  64.437500   81.187500
# Grass      61.928571   73.214286  67.271429   70.800000
# Ground     63.906250   95.750000  73.781250   84.843750
# Ice        63.458333   72.750000  72.000000   71.416667
# Normal     71.551020   73.469388  77.275510   59.846939
# Poison     63.571429   74.678571  67.250000   68.821429
# Psychic    81.491228   71.456140  70.631579   67.684211
# Rock       55.909091   92.863636  65.363636  100.795455
# ...

# %%
df.groupby(["type1"])[["Speed","Attack","HP","Defense"]].agg([np.mean,max,min])
# Out:
#                Speed               Attack                  HP           \
#                 mean  max min        mean  max min       mean  max min
# type1
# Bug        61.681159  160   5   70.971014  185  10  56.884058   86   1
# Dark       76.161290  125  20   88.387097  150  50  66.806452  126  35
# Dragon     83.031250  120  40  112.125000  180  50  83.312500  125  41
# Electric   84.500000  140  35   69.090909  123  30  59.795455   90  20
# Fairy      48.588235   99  15   61.529412  131  20  74.117647  126  35
# Fighting   66.074074  118  25   96.777778  145  35  69.851852  144  30
# Fire       74.442308  126  20   84.769231  160  30  69.903846  115  38
# Flying    102.500000  123  55   78.750000  115  30  70.750000   85  40
# Ghost      64.343750  130  20   73.781250  165  30  64.437500  150  20
# Grass      61.928571  145  10   73.214286  132  27  67.271429  123  30
# Ground     63.906250  120  10   95.750000  180  40  73.781250  115  10
# ...

# %%
df.pivot_table(values='Speed',index='type1').sort_values('Speed')
### FLYING HAVE THE MOST SPEED on an Average and Fairy has the least Speed on average
# Out:
#                Speed
# type1
# Fairy      48.588235
# Steel      55.259259
# Rock       55.909091
# Bug        61.681159
# Grass      61.928571
# Ice        63.458333
# Poison     63.571429
# Ground     63.906250
# Ghost      64.343750
# Water      65.964286
# Fighting   66.074074
# Normal     71.551020
# Fire       74.442308
# Dark       76.161290
# Psychic    81.491228
# Dragon     83.031250
# Electric   84.500000
# Flying    102.500000

# %%
### IN LEGENDARY
##  FLYING POKEMONS HAVE THE MOST SPEED
### ATTACK is best for Ground Legendary pokemons
### ROCK HAVE THE BEST DEFENCE
df[df.loc[:,['type1','Speed','Legendary']]['Legendary']==True].groupby(['type1'])[['Speed','Attack','Defense']].mean().sort_values(by='Defense')
# Out:
#                Speed      Attack     Defense
# type1
# Electric  106.750000   98.750000   75.000000
# Flying    116.000000  107.500000   75.000000
# Grass     111.666667   97.666667   82.333333
# Psychic   115.714286  122.142857   88.214286
# Dark      112.000000  110.500000   92.500000
# Fairy      99.000000  131.000000   95.000000
# Fire       85.400000  109.000000   98.200000
# Water      91.250000  111.250000   98.750000
# Ice        67.500000   67.500000  100.000000
# Dragon    100.833333  126.666667  100.083333
# Ghost      90.000000  110.000000  110.000000
# Normal    110.000000  140.000000  115.000000
# Ground     93.000000  150.000000  120.000000
# Steel      87.000000   96.250000  124.750000
# Rock       79.500000  122.250000  137.500000

# %%
legendary = df[df['Legendary']==True]
df[df['Legendary']==True]['HP'].hist(alpha=0.7,label='Legendary')
df[df['Legendary']==False]['HP'].hist(alpha=0.7,label='NL')
# Out:
# <AxesSubplot:>

# %%
### CHECK IF ANY COLUMN IS NA
df.isna().any()
# Out:
# #             False
# Name          False
# type1         False
# type2          True
# HP            False
# Attack        False
# Defense       False
# Sp. Atk       False
# Sp. Def       False
# Speed         False
# Generation    False
# Legendary     False
# dtype: bool
